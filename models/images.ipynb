xfd\xefo\xf9Y\x8f\xfey/V\xc4\x8b\x88\x88\x88\x88\x18\x80\x89\xe8T\xe5\xdf#/Aq$\x1f\x1e\x8e\xc4\x8a\x1f\r\x92~\xd8\x1fiSV\xea\xc5\xd6\xe6j\xc8K\xfc{N\xce\xd5.\xb7\xf5?:\xf9\xe1\x0eo\x97O\x16\xb0\x89\x88\x88\x88\x88\x01\x98\x88NS\x00\xb6\x0c "\x00Dx\x84D\x04\xc4#\xb4E_\x814-=\xa6\xf5$\xe3\xd8\x8c\x11\xaf~7\xda\xa8\xf1\xe6\x87\xdb\xe7\x8a\xe1\xe4\xc7\x8d\xd5\xfd\x1c\xfda\x00\xa6\xfd\xe6\x0e#"\xa2\xae~\xd8t\xfdc~\xf4\x17M""\xdc=""\xc4\xd7\xb7\'\xb5\xf5=\x1c>\x90\x88\x04\xe7A\x13\x11\x11\x111\x00\x13\xd1\xe9T\xbcl\xc2\xa7\xa8\x08BE!-\xa0\x1a\xe0\x80D\x84{ia2\x99\xae\x13\xac\xb7A\xd6\x960\x93u\xeb\xdfBxD\xacF\x8a\xcd\x ...

# %%
from models import Thumbnail

# %%
db_rec = Thumbnail(class_id=76, image=image_data)
# Out:
# /tmp/ipykernel_17981/2772976320.py:1: SAWarning: relationship 'Teacher.user' will copy column user.id to column teacher.user_id, which conflicts with relationship(s): 'User.teacher' (copies user.id to teacher.user_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="teacher"' to the 'Teacher.user' relationship. (Background on this error at: https://sqlalche.me/e/14/qzyx)
#   db_rec = Thumbnail(class_id=76, image=image_data)
# /tmp/ipykernel_17981/2772976320.py:1: SAWarning: relationship 'ClassUser.class_obj' will copy column class.id to column class_user.class, which conflicts with relationship(s): 'Class.class_users' (copies class.id to class_user.class). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="class_users"' to the 'ClassUser.class_obj' relationship. (Background on this error at: https://sqlalche.me/e/14/qzyx)
#   db_rec = Thumbnail(class_id=76, image=image_data)
# /tmp/ipykernel_17981/2772976320.py:1: SAWarning: relationship 'Request.class_obj' will copy column class.id to column request.class, which conflicts with relationship(s): 'Class.requests' (copies class.id to request.class). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="requests"' to the 'Request.class_obj' relationship. (Background on this error at: https://sqlalche.me/e/14/qzyx)
#   db_rec = Thumbnail(class_id=76, image=image_data)
# /tmp/ipykernel_17981/2772976320.py:1: SAWarning: relationship 'Message.cls' will copy column class.id to column message.class_, which conflicts with relationship(s): 'Class.messages' (copies class.id to message.class_). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="messages"' to the 'Message.cls' relationship. (Background on this error at: https://sqlalche.me/e/14/qzyx)
#   db_rec = Thumbnail(class_id=76, image=image_data)

# %%
session.add(db_rec)
session.commit()
